# %%
import pandas as pd
import numpy as no
import matplotlib.pyplot as plt

print("Hello World")
# Out:
# C:\Users\user\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# Hello World

# %%
coronaData = pd.read_csv("covid.csv", encoding="cp949")

coronaData
# Out:
#            서울시 기준일  서울시 확진자  서울시 추가 확진  서울시 사망         전국 기준일     전국 확진  \
# 0    2022.04.14.00  3275574      24976    4230  2022.04.14.00  15979061
# 1    2022.04.13.00  3250603      33076    4176  2022.04.13.00  15830644
# 2    2022.04.12.00  3217532      39518    4152  2022.04.12.00  15635274
# 3    2022.04.11.00  3178037      14247    4116  2022.04.11.00  15424598
# 4    2022.04.10.00  3163790      28901    4070  2022.04.10.00  15333670
# ..             ...      ...        ...     ...            ...       ...
# 796    20.02.09.18       10          0       0    20.02.09.18        27
# 797    20.02.08.18       10          0       0    20.02.08.18        24
# 798    20.02.07.18       10          0       0    20.02.07.18        24
# 799    20.02.06.09       11          0       0    20.02.06.09        24
# 800    20.02.05.15        8          0       0    20.02.05.15        18
#
#      전국 추가 확진  전국 당일 사망자
# 0      148443      318.0
# 1      195419      184.0
# ...

# %%
coronaData = coronaData[::-1]

coronaData
# Out:
#            서울시 기준일  서울시 확진자  서울시 추가 확진  서울시 사망         전국 기준일     전국 확진  \
# 0    2022.04.14.00  3275574      24976    4230  2022.04.14.00  15979061
# 1    2022.04.13.00  3250603      33076    4176  2022.04.13.00  15830644
# 2    2022.04.12.00  3217532      39518    4152  2022.04.12.00  15635274
# 3    2022.04.11.00  3178037      14247    4116  2022.04.11.00  15424598
# 4    2022.04.10.00  3163790      28901    4070  2022.04.10.00  15333670
# ..             ...      ...        ...     ...            ...       ...
# 796    20.02.09.18       10          0       0    20.02.09.18        27
# 797    20.02.08.18       10          0       0    20.02.08.18        24
# 798    20.02.07.18       10          0       0    20.02.07.18        24
# 799    20.02.06.09       11          0       0    20.02.06.09        24
# 800    20.02.05.15        8          0       0    20.02.05.15        18
#
#      전국 추가 확진  전국 당일 사망자
# 0      148443      318.0
# 1      195419      184.0
# ...

# %%
koreaData = coronaData["전국 추가 확진"]
koreaData
# Out:
# 0      148443
# 1      195419
# 2      210755
# 3       90928
# 4      164481
#         ...
# 796         0
# 797         0
# 798         0
# 799         0
# 800         0
# Name: 전국 추가 확진, Length: 801, dtype: int64

# %%
plt.rc("font", family="Malgun Gothic")

plt.plot(koreaData)

plt.xlabel("날짜")
plt.ylabel("1일 신규 확진자 수")

plt.show()
