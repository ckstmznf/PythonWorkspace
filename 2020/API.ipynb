# %% [markdown]
# # API
#
# <p>다양한 API를 만든다.</p>
#
#
#
# ## API목록
# * Corona API

# %%
def del_g(text):
    """문자열에 괄호와 괄호 안에 문자들을 지운다."""
    index1 = text.index("(")
    index2 = text.index(")")

    text = text.replace(text[index1:index2+1], "")
    print(text)
    return text

# %%
# !pip install requests
# !pip install bs4

# %%
# !pip list

# %% [markdown]
# <style>
#     .README {
#         display : inline;
#         color : red;
#         font-weight: bold;
#
#         background-color: aliceblue;
#     }
# </style>
# # Corona API
#
# <p class="README">이 API는 공공재입니다. 누구에게 저작권이 있는 게 아닌 모두가 마음대로 사용할 수 있는 API입니다.</p>
# <p>다양한 역할을 하는 Corona API<br>챗봇, 웹사이트 등에 활용합니다.</p>
#
# ## 정보를 가져올 사이트
# <a href="http://ncov.mohw.go.kr/bdBoardList_Real.do?brdId=1&brdGubun=11&ncvContSeq=&contSeq=&board_id=&gubun="><button>CLICK</button></a>
#
# ## 들어있는 정보
#
# * 기준 시각
# * 현재 총 확진자
# * 전날 대비 증가 확진자
# * 전날 대비 증가 확진자중 국내발생
# * 전날 대비 증가 확진자중 해외유입
# * 현재 치료중 수
# * 현재 치료중 전날 대비 증가 수
# * 현재 사망자 수
# * 현재 사망자 전날대비 증가 수
# * 현재 완치자 수
# * 현재 완치자 전날대비 증가 수

# %%
def coronaAPI():
    from requests import get
    from bs4 import BeautifulSoup

    url = "http://ncov.mohw.go.kr/bdBoardList_Real.do?brdId=1&brdGubun=11&ncvContSeq=&contSeq=&board_id=&gubun="
    html = get(url).text
    soup = BeautifulSoup(html, "html")
    data = soup.find("body")

    coronaApi = {
        "API Name" : "Corona API",
        "Site" : "http://ncov.mohw.go.kr/bdBoardList_Real.do?brdId=1&brdGubun=11&ncvContSeq=&contSeq=&board_id=&gubun=",
        "README" : "이 API는 공공재 입니다. 누구에게 저작권이 있는게 아닌 모두가 마음대로 사용할수 있는 API입니다."
    }
    
    criteria = data.find("span", class_="t_date").text.split("기")[0][1:-1] # 기준이 되는 시각을 가져와서 저장한다.
    coronaApi["criteria"] = criteria


    real_data = data.find("div", class_="caseTable").find_all(class_="ca_value")



    total = real_data[0].text #현재 총 확진자수

    total_add_all = real_data[1].find_all("p", class_="inner_value")[0].text #전날 대비 증가 확진자
    total_add_in = real_data[1].find_all("p", class_="inner_value")[1].text #전날 대비 증가 확진자중 국내발생
    total_add_out = real_data[1].find_all("p", class_="inner_value")[2].text #전날 대비 증가 확진자중 해외유입

    heal = real_data[2].text #완치 환자수
    heal_add = real_data[3].find("span").text #완치 환자수 전날 대비 증가수

    ing = real_data[4].text #현재 치료중 환자 수
    ing_add = real_data[5].find("span").text #현재 치료중 환자수 전날 대비 증가수

    pass_away = real_data[6].text #사망자수
    pass_away_add = real_data[7].find("span").text #사망자수 전날대비 증가수

    coronaApi["total"] = total
    coronaApi["total_add_all"] = total_add_all
    coronaApi["total_add_in"] = total_add_in
    coronaApi["total_add_out"] = total_add_out

    coronaApi["heal"] = heal
    coronaApi["heal_add"] = heal_add

    coronaApi["ing"] = ing
    coronaApi["ing_add"] = ing_add

    coronaApi["pass_away"] = pass_away
    coronaApi["pass_away_add"] = pass_away_add
    
    return coronaApi


api = coronaAPI()
print(f"오늘의 신규 확진자 : {api['total_add_all']}")
# Out:
# 오늘의 신규 확진자 : + 762

# %%
coronaAPI()
# Out:
# {'API Name': 'Corona API',
#  'Site': 'http://ncov.mohw.go.kr/bdBoardList_Real.do?brdId=1&brdGubun=11&ncvContSeq=&contSeq=&board_id=&gubun=',
#  'README': '이 API는 공공재 입니다. 누구에게 저작권이 있는게 아닌 모두가 마음대로 사용할수 있는 API입니다.',
#  'criteria': '7.1. 00시',
#  'total': '157,723',
#  'total_add_all': '+ 762',
#  'total_add_in': '712',
#  'total_add_out': '50',
#  'heal': '148,024',
#  'heal_add': '+ 331',
#  'ing': '7,678',
#  'ing_add': '+ 428',
#  'pass_away': '2,021',
#  'pass_away_add': '+ 3'}

# %% [markdown]
# # PAPAGO API

# %%
import os
import sys
import urllib.request
import requests as re
import json

def get_translation(source, target, text):
    client_id = "KiKBI7U6MP7_ETeviBYf"
    client_secret = "N_t5x8fBG_"
    encText = urllib.parse.quote(text)
    data = f"source={source}&target={target}&text=" + encText
    url = "https://openapi.naver.com/v1/papago/n2mt"
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    
    if(rescode==200):
        response_body = json.loads(response.read().decode("utf-8"))
        
        return response_body
    #     print(response_body.decode('utf-8'))
    else:
        return rescode
#         print("Error Code:" + rescode)



def translation(source, target, text):
    translation = get_translation(source, target, text)

    translation_data = translation["message"]["result"]
    s_lang = translation_data["srcLangType"]
    t_lang = translation_data["tarLangType"]
    translation_text = translation_data["translatedText"]

    return {"s_lang" : s_lang, "t_lang" : t_lang, "text" : translation_text}
#     print(f"{s_lang} -> {t_lang} / {translation_text}")

def all(s_lang, t_lang, text):
    first = translation(s_lang, "ja", text)
    scond = translation("ja", t_lang, first["text"])
    direct = translation(s_lang, t_lang, text)
    
    
    if s_lang == "ko":
        s_lang = "한국어"
        t_lang = "영어"
    else:
        s_lang = "영어"
        t_lang = "한국어"
    return {"source_lang" : s_lang, "target_lang" : t_lang, "text" : text, "indirect" : scond, "direct" : direct}

def n_to_brTag(text):
    return text.replace("\n", "<br>")


# text_en = """Hello, viewers. Thank you for clicking on this video. I’m Ronnie Drain, and
# I’ve been a personal fitness trainer for over 15 years. Today, I’d like to tell
# you about my channel, Build Your Body. On my channel, you can watch
# videos showing you how to do a variety of exercises that you can do at
# home or at your office. If you’ve experienced difficulty exercising regularly,
# my videos can provide easy guidelines and useful resources on exercise
# routines. New videos will be uploaded every Friday. Visit my channel and
# build a stronger, healthier body."""

# text_ko = """동해 물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세.
# 무궁화 삼천리 화려 강산
# 대한 사람, 대한으로 길이 보전하세."""

# t = all("ko", "en", text_ko)
# print(f'{"ko"}->{"ja"}->{"en"}\n\n{t["indirect"]["text"]}\n\n{"ko"}->{"en"}\n\n{t["direct"]["text"]}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3e69c25ee4b3> in <module>
#      66
#      67 t = all("ko", "en", text_ko)
# ---> 68 print(f'{"ko"}->{"ja"}->{"en"}\n\n{t["indircet"]["text"]}\n\n{"ko"}->{"en"}\n\n{t["direct"]["text"]}')
#
# KeyError: 'indircet'

# %%
text = "Hello World\nkgjfkjfdlsdf\nfkjdfdjfklj"
def n_to_brTag(text):
    return text.replace("\n", "<br>")

text = n_to_brTag(text)
text
# Out:
# 'Hello World<br>kgjfkjfdlsdf<br>fkjdfdjfklj'

# %%
t["indircet"]["text"]
# Out:
# "East Seato the point where the water and Mt. Baekdu dry up and become sour\nLong live our country by the protection of God.\nMugunghwa 3,000 ri Gaesan Mountain\nLet's live longer in Korea."

# %%
client_id = "KiKBI7U6MP7_ETeviBYf"
client_secret = "N_t5x8fBG_"
encText = urllib.parse.quote(text)
data = f"source={"en"}&target={"jp"}&text=" + encText
url = "https://openapi.naver.com/v1/papago/n2mt"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()

if(rescode==200):
    response_body = json.loads(response.read().decode("utf-8"))

#     return response_body
    print(response_body)
# else:
#     return rescode
# #         print("Error Code:" + rescode)
# Out:
#   File "<ipython-input-73-118fd9e4c1e3>", line 4
#     data = f"source={"en"}&target={"jp"}&text=" + encText
#                        ^
# SyntaxError: invalid syntax

# %%
{"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"ko","tarLangType":"en","translatedText":"Hello","engineType":"PRETRANS","pivot":null}}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0efadbf84a91> in <module>
# ----> 1 {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"ko","tarLangType":"en","translatedText":"Hello","engineType":"PRETRANS","pivot":null}}}
#
# NameError: name 'null' is not defined

# %% [markdown]
# # 국립국어원 에이피아이

# %%
import bs4 as bs
import requests as re


def korean(q):
    key = "7BA67A89E3C3F2DC85DAB600D94A399C"
    # q = "가설"
    url = f"https://stdict.korean.go.kr/api/search.do?certkey_no=2471&key={key}&type_search=search&q={q}"
    html = re.get(url).text
    soup = bs.BeautifulSoup(html, "xml")

    # data = soup.find_all("item")
    data = soup.find_all("definition")

    data = [i.text for i in data]

    return data

# %%
words = [
    "가변성", "가설", "가식", "가정", "간과", "간접적", "간주", "간파", "감각적 이미지", "감성적", "감수성", "감안", "감정이입",
    "감정적", "감지", "감화", "감흥", "강구", "강호가도", "강화", "개괄", "개념적", "개방적", "개별성", "개연성", "객관적", "객관적 상관물",
    "객관화", "거시적", "검증", "격동", "격앙", "격정", "견지", "결부", "겸양"
]

data = {}

for i in words:
    print(f"==={i}===")
    for j in korean(i):
        print(j + "\n")
    print("\n\n\n")
    data[i] = input()
# Out:
# ===가변성===
# 일정한 조건에서 변할 수 있는 성질.
#
#
#
#
#
# 일정한 조건에서 변할 수 있는 성질.
# ===가설===
# 덧붙이거나 추가하여 설치함.
#
# 전깃줄이나 전화선, 교량 따위를 공중에 건너질러 설치함.
#
# 임시로 설치함.
#
# 어떤 사실을 설명하거나 어떤 이론 체계를 연역하기 위하여 설정한 가정. 이로부터 이론적으로 도출된 결과가 관찰이나 실험에 의하여 검증되면, 가설의 위치를 벗어나 일정한 한계 안에서 타당한 진리가 된다.
#
# 길거리에 떠도는 말이나 화젯거리.
#
#
#
#
#
# pass
# ===가식===
# 어떤 것을 꾸밈.
#
# 종자나 모종을 제자리에 심을 때까지 임시로 딴 곳에 심는 일.
#
# 말이나 행동 따위를 거짓으로 꾸밈.
#
# 조선 시대에, 관원이 집안의 기제사(忌祭祀) 때 받던 짧은 휴가.
#
#
#
#
#
# 말이나 행동 따위를 거짓으로 꾸밈.
# ===가정===
# 물품, 비용, 인원 따위를 정한 수 이상으로 더 늘림.
#
# ‘피리’를 달리 이르는 말. 중국 후한 때 채옹이 가정관(柯亭館)의 대나무 서까래로 피리를 만들었다는 고사에서 유래한다.
#
# 가혹한 정치.
#
# 예전에, 집에서 부리던 남자 일꾼.
#
# 집안을 다스리는 일.
#
# 한 가족이 생활하는 집.
#
# 사실이 아니거나 또는 사실인지 아닌지 분명하지 않은 것을 임시로 인정함.
#
# 광물이 결정의 외형은 유지한 채 내부는 다른 결정형을 나타내는 것. 예를 들어 황철석의 결정이 본디의 외형을 지니면서 내부로는 갈철석으로 바뀌어 있거나, 중정석의 겉에 석영이 남아 있는 따위를 이른다.
#
# 중국 명나라 세종 때의 연호(1522~1566).
#
# ‘이곡’의 호.
#
#
#
#
#
# 사실이 아니거나 또는 사실인지 아닌지 분명하지 않은 것을 임시로 인정함.
# ===간과===
# 방패와 창이라는 뜻으로, 전쟁에 쓰는 병기를 통틀어 이르는 말.
#
# 큰 관심 없이 대강 보아 넘김.
#
# ...

# %%
# new_data = []
words = [
    "새옹지마", "설상가상", "설왕설래", "소탐대실", "속수무책", "수원수구",
    "수구초심", "수수방관", "수주대토", "순망치한", "식자우환", "아전인수",
    "안분지족", "안빈낙도",
]

# data = {}


for i in words:
    print(f"==={i}===")
    for j in korean(i):
        print(j + "\n")
    print("\n\n\n")
    new_data.append({"title" : i, "ex" : input()})
# Out:
# ===새옹지마===
# 인생의 길흉화복은 변화가 많아서 예측하기가 어렵다는 말. 옛날에 새옹이 기르던 말이 오랑캐 땅으로 달아나서 노인이 낙심하였는데, 그 후에 달아났던 말이 준마를 한 필 끌고 와서 그 덕분에 훌륭한 말을 얻게 되었으나 아들이 그 준마를 타다가 떨어져서 다리가 부러졌으므로 노인이 다시 낙심하였는데, 그로 인하여 아들이 전쟁에 끌려 나가지 아니하고 죽음을 면할 수 있었다는 이야기에서 유래한다. 중국 ≪회남자≫의 ‘인간훈(人間訓)’에 나오는 말이다.
#
#
#
#
#
# 인생의 길흉화복은 변화가 많아서 예측하기가 어렵다는 말. 옛날에 새옹이 기르던 말이 오랑캐 땅으로 달아나서 노인이 낙심하였는데, 그 후에 달아났던 말이 준마를 한 필 끌고 와서 그 덕분에 훌륭한 말을 얻게 되었으나 아들이 그 준마를 타다가 떨어져서 다리가 부러졌으므로 노인이 다시 낙심하였는데, 그로 인하여 아들이 전쟁에 끌려 나가지 아니하고 죽음을 면할 수 있었다는 이야기에서 유래한다. 중국 ≪회남자≫의 ‘인간훈(人間訓)’에 나오는 말이다.
# ===설상가상===
# 눈 위에 서리가 덮인다는 뜻으로, 난처한 일이나 불행한 일이 잇따라 일어남을 이르는 말.
#
#
#
#
#
# 눈 위에 서리가 덮인다는 뜻으로, 난처한 일이나 불행한 일이 잇따라 일어남을 이르는 말.
# ===설왕설래===
# 서로 변론을 주고받으며 옥신각신함. 또는 말이 오고 감.
#
#
#
#
#
# 서로 변론을 주고받으며 옥신각신함. 또는 말이 오고 감.
# ===소탐대실===
# 작은 것을 탐하다가 큰 것을 잃음.
#
#
#
#
#
# 작은 것을 탐하다가 큰 것을 잃음.
# ===속수무책===
# 손을 묶은 것처럼 어찌할 도리가 없어 꼼짝 못 함.
#
#
#
#
#
# 손을 묶은 것처럼 어찌할 도리가 없어 꼼짝 못 함.
# ===수원수구===
# 누구를 원망하고 누구를 탓하겠냐는 뜻으로, 남을 원망하거나 탓할 것이 없음을 이르는 말.
#
#
#
#
#
# ...

# %%
new_data = [{'title': '가렴주구', 'ex': '세금을 가혹하게 거두어들이고, 무리하게 재물을 빼앗음.'},
 {'title': '각골난망', 'ex': '남에게 입은 은혜가 뼈에 새길 만큼 커서 잊히지 아니함.'},
 {'title': '감언이설', 'ex': '귀가 솔깃하도록 남의 비위를 맞추거나 이로운 조건을 내세워 꾀는 말.'},
 {'title': '감탄고토',
  'ex': '달면 삼키고 쓰면 뱉는다는 뜻으로, 자신의 비위에 따라서 사리의 옳고 그름을 판단함을 이르는 말.'},
 {'title': '갑론을박', 'ex': '여러 사람이 서로 자신의 주장을 내세우며 상대편의 주장을 반박함.'},
 {'title': '개과천선', 'ex': '지난날의 잘못이나 허물을 고쳐 올바르고 착하게 됨.'},
 {'title': '건강부회', 'ex': 'pass'},
 {'title': '견원지간', 'ex': '개와 원숭이의 사이라는 뜻으로, 사이가 매우 나쁜 두 관계를 비유적으로 이르는 말.'},
 {'title': '경거망동', 'ex': '경솔하여 생각 없이 망령되게 행동함. 또는 그런 행동.'},
 {'title': '고립무원', 'ex': '고립되어 구원을 받을 데가 없음.'},
 {'title': '고진감래', 'ex': '쓴 것이 다하면 단 것이 온다는 뜻으로, 고생 끝에 즐거움이 옴을 이르는 말.'},
 {'title': '공평무사', 'ex': '공평하여 사사로움이 없음.'},
 {'title': '과유불급',
  'ex': '정도를 지나침은 미치지 못함과 같다는 뜻으로 , 중용(中庸)이 중요함을 이르는 말. ≪논어≫의 <선진편(先進篇)>에 나오는 말이다.'},
 {'title': '구우일모',
  'ex': '아홉 마리의 소 가운데 박힌 하나의 털이란 뜻으로, 매우 많은 것 가운데 극히 적은 수를 이르는 말.'},
 {'title': '구중심처', 'ex': '밖으로 잘 드러나지 않는 깊숙한 곳.'},
 {'title': '구중굴궐', 'ex': '겹겹이 문으로 막은 깊은 궁궐이라는 뜻으로, 임금이 있는 대궐 안을 이르는 말.'},
 {'title': '근묵자흑',
  'ex': ' 먹을 가까이하는 사람은 검어진다는 뜻으로, 나쁜 사람과 가까이 지내면 나쁜 버릇에 물들기 쉬움을 비유적으로 이르는 말.'}]

# %%
new_data
# Out:
# [{'title': '가렴주구', 'ex': '세금을 가혹하게 거두어들이고, 무리하게 재물을 빼앗음.'},
#  {'title': '각골난망', 'ex': '남에게 입은 은혜가 뼈에 새길 만큼 커서 잊히지 아니함.'},
#  {'title': '감언이설', 'ex': '귀가 솔깃하도록 남의 비위를 맞추거나 이로운 조건을 내세워 꾀는 말.'},
#  {'title': '감탄고토',
#   'ex': '달면 삼키고 쓰면 뱉는다는 뜻으로, 자신의 비위에 따라서 사리의 옳고 그름을 판단함을 이르는 말.'},
#  {'title': '갑론을박', 'ex': '여러 사람이 서로 자신의 주장을 내세우며 상대편의 주장을 반박함.'},
#  {'title': '개과천선', 'ex': '지난날의 잘못이나 허물을 고쳐 올바르고 착하게 됨.'},
#  {'title': '건강부회', 'ex': 'pass'},
#  {'title': '견원지간', 'ex': '개와 원숭이의 사이라는 뜻으로, 사이가 매우 나쁜 두 관계를 비유적으로 이르는 말.'},
#  {'title': '경거망동', 'ex': '경솔하여 생각 없이 망령되게 행동함. 또는 그런 행동.'},
#  {'title': '고립무원', 'ex': '고립되어 구원을 받을 데가 없음.'},
#  {'title': '고진감래', 'ex': '쓴 것이 다하면 단 것이 온다는 뜻으로, 고생 끝에 즐거움이 옴을 이르는 말.'},
#  {'title': '공평무사', 'ex': '공평하여 사사로움이 없음.'},
#  {'title': '과유불급',
#   'ex': '정도를 지나침은 미치지 못함과 같다는 뜻으로 , 중용(中庸)이 중요함을 이르는 말. ≪논어≫의 <선진편(先進篇)>에 나오는 말이다.'},
#  {'title': '구우일모',
#   'ex': '아홉 마리의 소 가운데 박힌 하나의 털이란 뜻으로, 매우 많은 것 가운데 극히 적은 수를 이르는 말.'},
# ...

# %%
new_data
# Out:
# [{'title': '가렴주구', 'ex': '세금을 가혹하게 거두어들이고, 무리하게 재물을 빼앗음.'},
#  {'title': '각골난망', 'ex': '남에게 입은 은혜가 뼈에 새길 만큼 커서 잊히지 아니함.'},
#  {'title': '감언이설', 'ex': '귀가 솔깃하도록 남의 비위를 맞추거나 이로운 조건을 내세워 꾀는 말.'},
#  {'title': '감탄고토',
#   'ex': '달면 삼키고 쓰면 뱉는다는 뜻으로, 자신의 비위에 따라서 사리의 옳고 그름을 판단함을 이르는 말.'},
#  {'title': '갑론을박', 'ex': '여러 사람이 서로 자신의 주장을 내세우며 상대편의 주장을 반박함.'},
#  {'title': '개과천선', 'ex': '지난날의 잘못이나 허물을 고쳐 올바르고 착하게 됨.'},
#  {'title': '건강부회', 'ex': 'pass'},
#  {'title': '견원지간', 'ex': '개와 원숭이의 사이라는 뜻으로, 사이가 매우 나쁜 두 관계를 비유적으로 이르는 말.'},
#  {'title': '경거망동', 'ex': '경솔하여 생각 없이 망령되게 행동함. 또는 그런 행동.'},
#  {'title': '고립무원', 'ex': '고립되어 구원을 받을 데가 없음.'},
#  {'title': '고진감래', 'ex': '쓴 것이 다하면 단 것이 온다는 뜻으로, 고생 끝에 즐거움이 옴을 이르는 말.'},
#  {'title': '공평무사', 'ex': '공평하여 사사로움이 없음.'},
#  {'title': '과유불급',
#   'ex': '정도를 지나침은 미치지 못함과 같다는 뜻으로 , 중용(中庸)이 중요함을 이르는 말. ≪논어≫의 <선진편(先進篇)>에 나오는 말이다.'},
#  {'title': '구우일모',
#   'ex': '아홉 마리의 소 가운데 박힌 하나의 털이란 뜻으로, 매우 많은 것 가운데 극히 적은 수를 이르는 말.'},
# ...

# %%
import requests as re
import bs4 as bs

url = "http://api.data.go.kr/openapi/tn_pubr_public_elesch_mskul_lc_api?schoolId=B100000658"
html = re.get(url).text
soup = bs.BeautifulSoup(html)

soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><response><header><resultcode>99</resultcode><resultmsg>class java.lang.NullPointerException</resultmsg></header></response>
# </body></html>

# %%
text = """가까운 제 눈썹 못 본다. 멀리 보이는 것은 용케 잘 보면서도 자기 눈앞에 가깝게 보이는 것은 잘못 봄.
가꿀 나무는 밑동을 높이 자른다. 어떠한 일이나 장래의 안목을 생각해서 미리부터 준비를 철저하게 해 두어야 함.
가난한 놈은 성도 없나. 가난한 사람이 괄시 당할 때 하는 말.
가난한 집 제사 돌아오듯 한다. 힘든 일이 자주 닥쳐옴.
가난한 놈이 기와집만 짓는다. 가난하고 구차하게 사는 사람일수록 공상만 많이 하여 허풍을 떤다.
가난한 집 족보 자랑하기. 가난뱅이 양반은 자신을 자랑할 만한 것이 없기 때문에 자기의 조상 자랑만 늘어놓음.
가는 님은 밉상이요, 오는 님은 곱상이다. 말려도 뿌리치고 가는 님은 미워도 기다리던 끝에 오는 님은 반갑다.
가는 방망이, 오는 홍두깨. 섣불리 남을 해치려다 도리어 큰 화를 입음.
가는 날이 장날이다. 어떤 일을 하려고 하는데 뜻하지 않은 일을 공교롭게 당함.
가랑잎에 불붙이기. 성미가 급하고 도량이 좁은 사람을 이르는 말.
가랑잎이 솔잎더러 바스락거린다고 한다. 자기 허물이 더 크고 많은 사람이 도리어 허물이 작은 사람을 나무람.
가루는 칠수록 고와지고 말은 할수록 거칠어진다. 가루는 체에 칠수록 고와지지만 말은 길어질수록 시비가 붙을 수 있
고 마침내는 말다툼까지 가게 되니 말을 삼가라는 말.
가마 속의 콩도 삶아야 먹는다. 아무리 쉬운 일이라도 움직여서 손대지 않으면 제게 이익이 돌아오지 않음.
가만히 먹으라니까 뜨겁다고 한다. 눈치 없이 비밀리 한 일을 드러냄.
가을에는 부지깽이도 덤벙인다. 추수하는 가을이 되면 농촌에는 일하지 않는 사람이 없을 정도로 매우 바쁨. 분주함을
비유적으로 이르거나 어떤 물건이 마구 대용됨을 이르기도 한다.
가을바람에 새털 날 듯 한다. 가을바람에 새털이 잘 날듯이 사람의 처신머리가 몹시 가볍다는 뜻.
가자니 태산이요 돌아서자니 숭산이라. 앞으로 가지도, 뒤로 돌아갈 수도 없는 난처한 지경.
가재 뒷걸음이나 게 옆걸음이나. 가재가 뒤로 가는 것이나 게가 옆으로 가는 것이나 앞으로 가지 않는 것은 매일반임.
가죽 없는 털은 없다. 세상만사는 모두 그 근원이 있다.
가지 따먹고 외수 한다. 남의 눈을 피하여 나쁜 짓하고 시치미를 뗀다.(외수: 남을 속이는 꾀)
갈치가 갈치 꼬리 문다. 친근한 사이에 서로 모함한다.
고뿔도 남을 안 준다. 감기까지도 안 줄 정도로 인색하다.
감나무 밑에서 입만 벌리고 있다. 요행수를 바람.
갓 쓰고 자전거 탄다. 어울리지 않아 어색하다.
강아지 메주 멍석 맡긴 것 같다. 믿지 못할 사람에게 일을 맡겨 놓고 마음이 놓이지 않아 불안해 함.
개같이 벌어서 정승같이 쓴다. 비천하게 벌어서라도 떳떳이 가장 보람 있게 쓴다.
개꼬리는 먹이를 탐내서 흔든다. 누구에게나 반가운 척하는 사람의 이면에는 대부분 야심이 숨겨져 있음.
개 꼬리 3년 두어도 황모 못 된다. 개 꼬리를 삼년씩이나 묻어두어도 황모(족제비의 꼬리털로 붓 매는데 씀.)는 안 된
다는 뜻으로 워낙 본성이 나쁜 것은 아무리 오래 되어도 좋게 변하지 않는다.
개는 잘 짖는다고 좋은 개는 아니다. 모름지기 사람은 말보다 처신을 잘해야 훌륭한 사람이다.
개도 무는 개는 돌아본다. 같은 개끼리도 사나운 개를 두려워하듯이, 사람도 악한 사람에게는 혹시 그 화를 입을까 하여
조심하고 잘 대해준다.
개똥참외도 먼저 맡은 놈이 임자다. 아무리 임자 없이 굴러다니는 물건이라도 먼저 와서 맡은 사람이 주인.
개 못된 것은 들에 나가 짖는다. 개는 집을 지키며 집에서 짖는 짐승인데 못된 개는 쓸데없이 들판에 나가 짖는다는
뜻으로, 제가 마땅히 해야 할 일은 하지 아니하고 아무 소용도 없는 데 가서 잘난 체하고 떠드는 행동을 이르는 말.
개미 나는 곳에 범 난다. 처음에는 작고 대수롭지 않던 것이 점점 커져서 나중에는 크고 무서운 것이 된다.
개 보름 쇠듯 한다. 명절날 맛 좋은 음식도 해 먹지 못하고 그냥 넘긴다.
개살구가 먼저 익는다. 맛없는 개살구가 맛좋은 참살구보다 먼저 익듯이 나쁜 일이 선한 것보다 더 발전하게 됨.
개살구가 지레 터진다. 되지 못한 사람이 오히려 잘난 체하며 뽐내거나 남보다 먼저 나섬."""

# %%
import requests as re
import bs4 as bs

url = "https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD"
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
html = re.get(url, headers = header).text
soup = bs.BeautifulSoup(html, 'html.parser')

soup#.find("table", class_="VTableTrend_table__POFel")#.find("tbody")#.find_all("tr", class_="VTableTrend_tr__VxB7i")
# Out:
# <!DOCTYPE html>
# ...

# %%
from os import replace
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

url="https://m.stock.naver.com/index.html#/domestic/stock/005930/total"
res=urlopen(url)
soup=BeautifulSoup(res, "web")

cprt=soup.find_all("tr", attrs={})
print(cprt)
Sr=[]
for cprt in cprt:
    Sr.append(cprt.get_text())

cnt=0

for i in range(len(Sr)):
    Sr[i]=Sr[i].strip()
    Sr[i]=Sr[i].replace(',','')
    for j in range(10):
        if str(j) in Sr[i]: cnt+=1
    if cnt==0: Sr[i]=[]
    cnt=0

Snr=[]

for i in range(len(Sr)):
    if Sr[i]!=[]:
        Snr.append(Sr[i])

print(Snr)
# Out:
# []
# []

# %%
def get_chung_code():
    for i in range(ord("B"), ord("Z") + 1):
        #print(i)

        url = "https://open.neis.go.kr/hub/schoolInfo?KEY=KEY=c8ff3a0bf27f4dbeb3fb11bb2e814016&ATPT_OFCDC_SC_CODE=" + chr(i) + "10"
        responce = re.get(url).text
        soup = bs.BeautifulSoup(responce, "xml")
        if(soup.find("MESSAGE").text == "해당하는 데이터가 없습니다."):
            continue
        data = soup.find_all("row")[0]

        print(f"{i - 65} : {data.find('ATPT_OFCDC_SC_NM').text}")
    
    chung_code = int(input("교육청을 선택하세요. : "))
    
    print("\n\n")
    return chr(chung_code + 65) + "10"

# %%
import requests as re
import bs4 as bs

#url = f"https://open.neis.go.kr/hub/hisTimetable?KEY={c8ff3a0bf27f4dbeb3fb11bb2e814016}&ATPT_OFCDC_SC_CODE=B10"url =



def get_school_code(chung_code, key):
    url = f"https://open.neis.go.kr/hub/schoolInfo?KEY=KEY=c8ff3a0bf27f4dbeb3fb11bb2e814016&SCHUL_NM={key}&ATPT_OFCDC_SC_CODE={chung_code}"

    responce = re.get(url).text
    soup = bs.BeautifulSoup(responce, "xml")
    data = soup.find_all("row")
    
    school_list = []
    for n, i in enumerate(data):
        name = i.find("SCHUL_NM").text
        code = i.find("SD_SCHUL_CODE").text
        
        school_list.append(code)
        print(f"{n + 1}, {name} : {code}")
    
    choice = int(input("학교를 선택하세요 : "))
    return school_list#[choice + 1]

chung_code = get_chung_code()
key = input("학교명 검색 : ")
get_school_data(chung_code, key)
# Out:
# 1 : 서울특별시교육청
# 2 : 부산광역시교육청
# 3 : 대구광역시교육청
# 4 : 인천광역시교육청
# 5 : 광주광역시교육청
# 6 : 대전광역시교육청
# 7 : 울산광역시교육청
# 8 : 세종특별자치시교육청
# 9 : 경기도교육청
# 10 : 강원도교육청
# 12 : 충청북도교육청
# 13 : 충청남도교육청
# 15 : 전라북도교육청
# 16 : 전라남도교육청
# 17 : 경상북도교육청
# 18 : 경상남도교육청
# 19 : 제주특별자치도교육청
# 21 : 재외한국학교교육청
# 교육청을 선택하세요. : 선린
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-2b1f649350af> in <module>
#      24     return school_list#[choice + 1]
#      25
# ---> 26 chung_code = get_chung_code()
#      27 key = input("학교명 검색 : ")
#      28 get_school_data(chung_code, key)
#
# <ipython-input-42-e10e9613a01d> in get_chung_code()
#      12         print(f"{i - 65} : {data.find('ATPT_OFCDC_SC_NM').text}")
#      13
# ---> 14     chung_code = int(input("교육청을 선택하세요. : "))
#      15
#      16     print("\n\n")
#
# ValueError: invalid literal for int() with base 10: '선린'

# %%
url = "https://open.neis.go.kr/hub/schoolInfo?KEY=KEY=c8ff3a0bf27f4dbeb3fb11bb2e814016&ATPT_OFCDC_SC_CODE=V10"
responce = re.get(url).text
soup = bs.BeautifulSoup(responce, "xml")
data = soup.find_all("row")
print(len(data))
# Out:
# 5

# %%
import requests as re
import json, time

def getUserData(user_name):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{user_name}?api_key=RGAPI-419c80a5-22c8-448e-9a6a-f3ddea40494e"
    html = re.get(url).text
    json_ = json.loads(html)
    return json_


def getUserNow(user_id):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/{user_id}?api_key=RGAPI-419c80a5-22c8-448e-9a6a-f3ddea40494e"
    html = re.get(url).text
    json_ = json.loads(html)
    
    json_

    
# user_id = "jQ3ybObylaZPDBmT_q5aUQXnnh_WUu0-FAbjAChnA8Q1r1Bg"
user_id = "2dmLP6F_klAFNwWo5nd73OGxmldAO6w08m8IlzEd6hT6LUQ"
url = f"https://kr.api.riotgames.com/lol/spectator/v4/active-games/by-summoner/{user_id}?api_key=RGAPI-419c80a5-28e-9ae4"
html = re.get(url).text
json_ = json.loads(html)

json_
# Out:
# {'status': {'message': 'Forbidden', 'status_code': 403}}

# %%
print(getUserData("insu1213")["id"])
print(getUserData("나도언니좋아해")["id"])
print(getUserData("Hide in bush")["id"])
# Out:
# kWB7Ls9bIGC2lUTjyNqPqc1aSZ25nX-xMzwEi8kPD84LTtw
# jQ3ybObylaZPDBmT_q5aUQXnnh_WUu0-FAbjAChnA8Q1r1Bg
# 2dmLP6F_klAFNwWo5nd73OGxmldAO6w08m8IlzEd6hT6LUQ
